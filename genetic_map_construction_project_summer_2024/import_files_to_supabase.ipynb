# %%
from pathlib import Path
import pandas as pd
import os
#import psycopg2
#import logging 

# configure logging
#logging.basicConfig(level = logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

#def connect_to_db():
#    try:
#        conn = psycopg2.connect(
 #           host="aws-0-us-east-1.pooler.supabase.com",
  #          database="postgres",
   #         user="postgres.hymndoayxvitvbukpqct",
    #        password="zAHfkaH9iH5j_fG",
     #       port="6543"
       # )
      #  logging.info("Connected to Supabase.")
       # return conn
   # except Exception as e:
    #    logging.error(f"Error connecting to database: {e}")
     #   return None
    
#walking through the file system 
def find_csv_files(start_dir):
    dataframes = []
    # Create a Path object for the starting directory
    start_path = Path(start_dir)
    # Iterate over all subfolders and files in the directory
    for file_path in start_path.rglob('*.csv'):
        print(f"Found CSV file: {file_path}")
        # Import the CSV file
        df = pd.read_csv(file_path, encoding = 'ISO-8859-1' )
        dataframes.append(df)
    return dataframes

def find_excel_files(start_dir):
    dataframes = []
    #create a path object for the starting directory
    start_path = Path(start_dir)
    #iterate over all subfolders and files in the directory
    for file_path in start_path.rglob('*.xls*'):
        print(f"Found Excel file: {file_path}")
        #import excel file
        df = pd.read_excel(file_path, engine = 'openpyxl')
        dataframes.append(df)
    return dataframes

def parse_texture_analyzer_files(file_path_list):
    parsed_TA_files = []
    for file_path in file_path_list:
        #extract sample IDs (LSH - X X X) from the 'Test ID' column
        sample_ids = file_path['Test ID'].str.extract(r'(LSH-\d+)')[0].dropna().unique()
        #select the average row
        average_row = file_path[file_path['Test ID'].str.contains('Average:', na = False)]
        #create a new data frame for the results
        columns_to_keep = file_path.columns[1:] #exclude the 'Test ID' column
        results = pd.DataFrame(columns = ['Sample ID'] + list(columns_to_keep))
        #populate the new data frame with sample IDs and corresponding averages
        for sample_id in sample_ids:
            row = {'Sample ID': sample_id}
            row.update(average_row.iloc[0, 1:].to_dict())
            results = pd.concat([results, pd.DataFrame([row])], ignore_index = True)
        parsed_TA_files.append(results)
    return parsed_TA_files
        
def parse_autotitrator_files(file_path_list):
    parsed_AT_files = []
    for file_path in file_path_list:
        print(f"Columns in {file_path}: {file_path.columns.tolist()}")
        sample_ids = []
        sample_sizes = []
        veq1_values = []
        est_values = []

        #variables to hold the current sample's data
        current_sample_id = None
        current_sample_size = None
        current_veq1 = None
        current_est = None
        #iterate through the dataframe to extract information
        for index, row in file_path.iterrows():
            if pd.notna(row.get('Name')) and "Sample Scope" in row.get('Name', ''):
                # Extract Sample ID (e.g., LSH-198)
                current_sample_id = row['Name'].split("LSH-")[1].split(")")[0]
            elif pd.notna(row.get('Value')) and "Sample size" in row.get('Name', ''):
                # Extract Sample Size
                current_sample_size = float(row['Value'].split()[0])
            elif pd.notna(row.get('Value')) and "VEQ1" in row.get('Name', ''):
                # Extract VEQ1
                current_veq1 = float(row['Value'].split()[0])
            elif pd.notna(row.get('Value')) and "EST" in row.get('Name', ''):
                # Extract EST
                current_est = float(row['Value'].split()[0])

            
                #after EST, we expect a complete set of data, so store it
                sample_ids.append(current_sample_id)
                sample_sizes.append(current_sample_size)
                veq1_values.append(current_veq1)
                est_values.append(current_est)

                #reset current sample variables (if multiple samples exist)
                current_sample_id = None
                current_sample_size = None
                current_veq1 = None
                current_est = None

            #create new data frame
        parsed_AT = pd.DataFrame({
            'unique id': sample_ids,
            'autotitration sample size (g)': sample_sizes,
            'autotitration veq1 (ml)': veq1_values,
            'autotitration est (pH)': est_values
        })
        parsed_AT_files.append(parsed_AT)
    return parsed_AT_files

#work through texture analyzer data
start_directory_TA = "/Users/nyssandey-bongo/Downloads/Summer2024_LSH_Data/Texture Analyzer"
texture_analyzer_file_paths = find_excel_files(start_directory_TA)
new_TA_df_list = parse_texture_analyzer_files(texture_analyzer_file_paths)

#work through autotitrator data
start_directory_AT = "/Users/nyssandey-bongo/Downloads/Summer2024_LSH_Data/Autotitrator"
autotitrator_file_paths = find_csv_files(start_directory_AT)
new_AT_df_list = parse_autotitrator_files(autotitrator_file_paths)

display(new_TA_df_list)
display(new_AT_df_list)

#def main():
    #connect to supabase
    #conn = connect_to_db()
    #if not conn:
     #   return  

#if __name__ == "__main__":
    #main()

#def close_db_connection(conn):
    #if conn:
     #   conn.close()
      #  logging.info("Database connection closed.")

#close database connection
#close_db_connection()
# Out:
# Found Excel file: /Users/nyssandey-bongo/Downloads/Summer2024_LSH_Data/Texture Analyzer/Harvest1/LSH_Harvest1_Part1_Results_TextureAnalyzer.xlsx
# Found Excel file: /Users/nyssandey-bongo/Downloads/Summer2024_LSH_Data/Texture Analyzer/Harvest1/LSH_redo1_LauraGiongo_Harvest1_TextureAnalyzer.xlsx
# Found Excel file: /Users/nyssandey-bongo/Downloads/Summer2024_LSH_Data/Texture Analyzer/Harvest1/LSH_Harvest1_Part2_Results_TextureAnalyzer.xlsx
# Found Excel file: /Users/nyssandey-bongo/Downloads/Summer2024_LSH_Data/Texture Analyzer/Harvest1/LSH_Harvest1_Part3_Results_TextureAnalyzer.xlsx
# Found Excel file: /Users/nyssandey-bongo/Downloads/Summer2024_LSH_Data/Texture Analyzer/Harvest1/LSH-Lib-Rep1-Harvest1.xlsx
# Found Excel file: /Users/nyssandey-bongo/Downloads/Summer2024_LSH_Data/Texture Analyzer/Harvest2/LSH-Lib-Rep1-Harvest2.xlsx
# Found Excel file: /Users/nyssandey-bongo/Downloads/Summer2024_LSH_Data/Texture Analyzer/Harvest2/LSH-Harvest2-Rep1-Part2.xlsx
# Found Excel file: /Users/nyssandey-bongo/Downloads/Summer2024_LSH_Data/Texture Analyzer/Harvest2/LSH-Harvest2-Rep1-Part1.xlsx
# Found Excel file: /Users/nyssandey-bongo/Downloads/Summer2024_LSH_Data/Texture Analyzer/Harvest4/LSH-Harvest4-Rep1-Part4.xlsx
# Found Excel file: /Users/nyssandey-bongo/Downloads/Summer2024_LSH_Data/Texture Analyzer/Harvest4/LSH-Harvest4-Rep1-Part5.xlsx
# Found Excel file: /Users/nyssandey-bongo/Downloads/Summer2024_LSH_Data/Texture Analyzer/Harvest4/LSH-Harvest4-Rep1-Part2.xlsx
# Found Excel file: /Users/nyssandey-bongo/Downloads/Summer2024_LSH_Data/Texture Analyzer/Harvest4/LSH-Harvest4-Rep1-Part3.xlsx
# Found Excel file: /Users/nyssandey-bongo/Downloads/Summer2024_LSH_Data/Texture Analyzer/Harvest4/LSH-Harvest4-Rep1-Part1.xlsx
# Found Excel file: /Users/nyssandey-bongo/Downloads/Summer2024_LSH_Data/Texture Analyzer/Harvest4/LSH-Harvest4-Rep1-Part6.xlsx
# Found Excel file: /Users/nyssandey-bongo/Downloads/Summer2024_LSH_Data/Texture Analyzer/Harvest3/LSH-Harvest3-Rep1-Part5.xlsx
# Found Excel file: /Users/nyssandey-bongo/Downloads/Summer2024_LSH_Data/Texture Analyzer/Harvest3/LSH-Harvest3-Rep1-Part4.xlsx
# Found Excel file: /Users/nyssandey-bongo/Downloads/Summer2024_LSH_Data/Texture Analyzer/Harvest3/LSH-Lib-Rep1-Harvest3.xlsx
# Found Excel file: /Users/nyssandey-bongo/Downloads/Summer2024_LSH_Data/Texture Analyzer/Harvest3/LSH-Harvest3-Rep1-Part3.xlsx
# Found Excel file: /Users/nyssandey-bongo/Downloads/Summer2024_LSH_Data/Texture Analyzer/Harvest3/LSH-Harvest3-Rep1-Part2.xlsx
# Found Excel file: /Users/nyssandey-bongo/Downloads/Summer2024_LSH_Data/Texture Analyzer/Harvest3/LSH-Harvest3-Rep1-Part1.xlsx
# Found Excel file: /Users/nyssandey-bongo/Downloads/Summer2024_LSH_Data/Texture Analyzer/Harvest3/LSH-Harvest3-Rep1-Part6.xlsx
# /var/folders/qv/j4x5cx0s7x12gysrydqswrh00000gn/T/ipykernel_38012/3820894961.py:64: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results = pd.concat([results, pd.DataFrame([row])], ignore_index = True)
# /var/folders/qv/j4x5cx0s7x12gysrydqswrh00000gn/T/ipykernel_38012/3820894961.py:64: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results = pd.concat([results, pd.DataFrame([row])], ignore_index = True)
# /var/folders/qv/j4x5cx0s7x12gysrydqswrh00000gn/T/ipykernel_38012/3820894961.py:64: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results = pd.concat([results, pd.DataFrame([row])], ignore_index = True)
# /var/folders/qv/j4x5cx0s7x12gysrydqswrh00000gn/T/ipykernel_38012/3820894961.py:64: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results = pd.concat([results, pd.DataFrame([row])], ignore_index = True)
# /var/folders/qv/j4x5cx0s7x12gysrydqswrh00000gn/T/ipykernel_38012/3820894961.py:64: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results = pd.concat([results, pd.DataFrame([row])], ignore_index = True)
# /var/folders/qv/j4x5cx0s7x12gysrydqswrh00000gn/T/ipykernel_38012/3820894961.py:64: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results = pd.concat([results, pd.DataFrame([row])], ignore_index = True)
# /var/folders/qv/j4x5cx0s7x12gysrydqswrh00000gn/T/ipykernel_38012/3820894961.py:64: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results = pd.concat([results, pd.DataFrame([row])], ignore_index = True)
# /var/folders/qv/j4x5cx0s7x12gysrydqswrh00000gn/T/ipykernel_38012/3820894961.py:64: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results = pd.concat([results, pd.DataFrame([row])], ignore_index = True)
# /var/folders/qv/j4x5cx0s7x12gysrydqswrh00000gn/T/ipykernel_38012/3820894961.py:64: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results = pd.concat([results, pd.DataFrame([row])], ignore_index = True)
# /var/folders/qv/j4x5cx0s7x12gysrydqswrh00000gn/T/ipykernel_38012/3820894961.py:64: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results = pd.concat([results, pd.DataFrame([row])], ignore_index = True)
# /var/folders/qv/j4x5cx0s7x12gysrydqswrh00000gn/T/ipykernel_38012/3820894961.py:64: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results = pd.concat([results, pd.DataFrame([row])], ignore_index = True)
# /var/folders/qv/j4x5cx0s7x12gysrydqswrh00000gn/T/ipykernel_38012/3820894961.py:64: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results = pd.concat([results, pd.DataFrame([row])], ignore_index = True)
# /var/folders/qv/j4x5cx0s7x12gysrydqswrh00000gn/T/ipykernel_38012/3820894961.py:64: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results = pd.concat([results, pd.DataFrame([row])], ignore_index = True)
# /var/folders/qv/j4x5cx0s7x12gysrydqswrh00000gn/T/ipykernel_38012/3820894961.py:64: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results = pd.concat([results, pd.DataFrame([row])], ignore_index = True)
# /var/folders/qv/j4x5cx0s7x12gysrydqswrh00000gn/T/ipykernel_38012/3820894961.py:64: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results = pd.concat([results, pd.DataFrame([row])], ignore_index = True)
# /var/folders/qv/j4x5cx0s7x12gysrydqswrh00000gn/T/ipykernel_38012/3820894961.py:64: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results = pd.concat([results, pd.DataFrame([row])], ignore_index = True)
# /var/folders/qv/j4x5cx0s7x12gysrydqswrh00000gn/T/ipykernel_38012/3820894961.py:64: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results = pd.concat([results, pd.DataFrame([row])], ignore_index = True)
# /var/folders/qv/j4x5cx0s7x12gysrydqswrh00000gn/T/ipykernel_38012/3820894961.py:64: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results = pd.concat([results, pd.DataFrame([row])], ignore_index = True)
# Found CSV file: /Users/nyssandey-bongo/Downloads/Summer2024_LSH_Data/Autotitrator/Harvest 2/LSH_Lib_Harvest2.csv
# Found CSV file: /Users/nyssandey-bongo/Downloads/Summer2024_LSH_Data/Autotitrator/Harvest 2/LSH_Population_Harvest2_Part2.csv
# Found CSV file: /Users/nyssandey-bongo/Downloads/Summer2024_LSH_Data/Autotitrator/Harvest 2/LSH_Population_Harvest2_Part1.csv
# Found CSV file: /Users/nyssandey-bongo/Downloads/Summer2024_LSH_Data/Autotitrator/Harvest 3/LSH_Population_Harvest3.csv
# Found CSV file: /Users/nyssandey-bongo/Downloads/Summer2024_LSH_Data/Autotitrator/Harvest 3/LSH_Lib_Harvest3.csv
# Found CSV file: /Users/nyssandey-bongo/Downloads/Summer2024_LSH_Data/Autotitrator/Harvest 4/LSH_Population_Harvest4_final.csv
# Found CSV file: /Users/nyssandey-bongo/Downloads/Summer2024_LSH_Data/Autotitrator/Harvest 4/LSH_Population_Harvest4_Part2.csv
# Found CSV file: /Users/nyssandey-bongo/Downloads/Summer2024_LSH_Data/Autotitrator/Harvest 4/LSH_Population_Harvest4_Part1.csv
# Found CSV file: /Users/nyssandey-bongo/Downloads/Summer2024_LSH_Data/Autotitrator/Harvest 1/LSH_Batch7_Harvest1_Autotitrator.csv
# Found CSV file: /Users/nyssandey-bongo/Downloads/Summer2024_LSH_Data/Autotitrator/Harvest 1/LSH_Lib_Harvest1_Autotitrator.csv
# Found CSV file: /Users/nyssandey-bongo/Downloads/Summer2024_LSH_Data/Autotitrator/Harvest 1/LSH_Batch8_Harvest1_Autotitrator.csv
# Found CSV file: /Users/nyssandey-bongo/Downloads/Summer2024_LSH_Data/Autotitrator/Harvest 1/LSH_Batch5_Harvest1_Autotitrator.csv
# Found CSV file: /Users/nyssandey-bongo/Downloads/Summer2024_LSH_Data/Autotitrator/Harvest 1/LSH_Batch2_Harvest1_Autotitrator.csv
# Found CSV file: /Users/nyssandey-bongo/Downloads/Summer2024_LSH_Data/Autotitrator/Harvest 1/LSH_Batch3_Harvest1_Autotitrator.csv
# Found CSV file: /Users/nyssandey-bongo/Downloads/Summer2024_LSH_Data/Autotitrator/Harvest 1/LSH_Batch4_Harvest1_Autotitrator.csv
# Found CSV file: /Users/nyssandey-bongo/Downloads/Summer2024_LSH_Data/Autotitrator/Harvest 1/LSH_Batch9_Harvest1_Autotitrator.csv
# Found CSV file: /Users/nyssandey-bongo/Downloads/Summer2024_LSH_Data/Autotitrator/Harvest 1/LSH_Batch1_Harvest1_Autotitrator.csv
# Found CSV file: /Users/nyssandey-bongo/Downloads/Summer2024_LSH_Data/Autotitrator/Harvest 1/LSH_Batch6_Harvest1_Autotitrator.csv
# Columns in                         Results Editor  \
# 0                             Raw Data
# 1                                 Name
# 2             Task Internal Id: T2035
# 3                                  NaN
# 4                                  NaN
# 5                                  NaN
# 6                                  NaN
# 7                                  NaN
# 8                                  NaN
# 9                                  NaN
# 10                                 NaN
# 11                                 NaN
# 12                                 NaN
# 13                                 NaN
# 14                                 NaN
# 15                                 NaN
# 16                                 NaN
# 17                                 NaN
# 18                                 NaN
# 19                                 NaN
# 20                                 NaN
# 21                                 NaN
# 22                                 NaN
# 23                                 NaN
# 24                                 NaN
# 25                                 NaN
# 26                                 NaN
# 27                                 NaN
# 28                                 NaN
# 29                                 NaN
# 30                                 NaN
# 31                                 NaN
# 32                                 NaN
# 33                                 NaN
# 34                                 NaN
# 35                                 NaN
# 36                                 NaN
# 37                                 NaN
# 38                                 NaN
# 39                                 NaN
# 40                                 NaN
# 41  7/11/2024 5:46:54 PMSystemInternal
#
#                                            Unnamed: 1  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3   Sample Scope: Sample scope: Scope 1/1, Sample ...
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
#
#                                            Unnamed: 2         Unnamed: 3  \
# 0                                                 NaN                NaN
# 1                                                 NaN                NaN
# 2                                                 NaN                NaN
# 3                                                 NaN                NaN
# 4      Method Function: Method function: Sample (S1)                 NaN
# 5                                                 NaN      Creation time
# 6                                                 NaN  Sample start time
# 7                                                 NaN        Sample size
# 8                                                 NaN  Correction factor
# 9                                                 NaN        Temperature
# 10                                                NaN            Density
# 11  Method Function: Method function: Titration st...                NaN
# 12                                                NaN      Creation time
# 13    Method Function: Method function: Stir (Stir1)                 NaN
# 14                                                NaN      Creation time
# 15  Method Function: Method function: Titration (E...                NaN
# 16                                                NaN      Creation time
# 17                                                NaN      Terminated at
# 18                                                NaN               EEQ1
# 19                                                NaN                 Q1
# 20                                                NaN               VEQ1
# 21                                                NaN                EST
# 22                                                NaN                VEX
# 23                                                NaN               VEND
# 24                                                NaN                  t
# 25                                                NaN               QEND
# 26                                                NaN                QEX
# 27  Method Function: Method function: Consumption ...                NaN
# 28                                                NaN      Creation time
# 29                                                NaN             Result
# 30                                                NaN     Decimal places
# 31                                                NaN          Substance
# 32                                                NaN                  M
# 33                                                NaN                  z
# 34    Method Function: Method function: Content (R2)                 NaN
# 35                                                NaN      Creation time
# 36                                                NaN             Result
# 37                                                NaN     Decimal places
# 38                                                NaN          Substance
# 39                                                NaN                  M
# 40                                                NaN                  z
# 41                                                NaN                NaN
#
#               Unnamed: 4   Unnamed: 5 Unnamed: 6
# 0                    NaN          NaN        NaN
# 1                  Value  Description        NaN
# 2                    NaN          NaN        NaN
# 3                    NaN          NaN        NaN
# 4                    NaN          NaN        NaN
# 5   7/11/2024 5:03:55 PM          NaN        NaN
# 6   7/11/2024 5:03:55 PM          NaN        NaN
# 7                2.007 g          NaN        NaN
# 8                   0.64          NaN        NaN
# 9                25.0 °C          NaN        NaN
# 10              1.0 g/mL          NaN        NaN
# 11                   NaN          NaN        NaN
# 12  7/11/2024 5:03:56 PM          NaN        NaN
# 13                   NaN          NaN        NaN
# 14  7/11/2024 5:04:05 PM          NaN        NaN
# 15                   NaN          NaN        NaN
# 16  7/11/2024 5:05:06 PM          NaN        NaN
# 17      Stop at endpoint          NaN        NaN
# 18                8.2 pH          NaN        NaN
# 19         0.507300 mmol          NaN        NaN
# 20              5.073 mL          NaN        NaN
# 21              3.001 pH          NaN        NaN
# 22                  0 mL          NaN        NaN
# 23              5.073 mL          NaN        NaN
# 24             00:59 min          NaN        NaN
# 25         0.507300 mmol          NaN        NaN
# 26           0.0000 mmol          NaN        NaN
# 27                   NaN          NaN        NaN
# 28  7/11/2024 5:06:16 PM          NaN        NaN
# 29             5.0730 mL          NaN        NaN
# 30                     4          NaN        NaN
# 31     Hydrochloric acid          NaN        NaN
# 32           36.46 g/mol          NaN        NaN
# 33                     1          NaN        NaN
# 34                   NaN          NaN        NaN
# 35  7/11/2024 5:06:16 PM          NaN        NaN
# 36            1.618 mL/g          NaN        NaN
# 37                     3          NaN        NaN
# 38     Hydrochloric acid          NaN        NaN
# 39           36.46 g/mol          NaN        NaN
# 40                     1          NaN        NaN
# 41                   NaN          NaN        1/1  : ['Results Editor', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6']
# Columns in                          Results Editor  \
# 0                              Raw Data
# 1                                  Name
# 2              Task Internal Id: T1929
# 3                                   NaN
# 4                                   NaN
# ...                                 ...
# 2590                                NaN
# 2591                                NaN
# 2592                                NaN
# 2593                                NaN
# 2594  6/1/2024 3:41:34 AMSystemInternal
#
#                                              Unnamed: 1  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3     Sample Scope: Sample scope: Scope 1/1, Sample ...
# 4                                                   NaN
# ...                                                 ...
# 2590                                                NaN
# 2591                                                NaN
# 2592                                                NaN
# 2593                                                NaN
# 2594                                                NaN
#
#                                           Unnamed: 2      Unnamed: 3  \
# 0                                                NaN             NaN
# 1                                                NaN             NaN
# 2                                                NaN             NaN
# 3                                                NaN             NaN
# 4     Method Function: Method function: Sample (S1)              NaN
# ...                                              ...             ...
# 2590                                             NaN  Decimal places
# 2591                                             NaN       Substance
# 2592                                             NaN               M
# 2593                                             NaN               z
# 2594                                             NaN             NaN
#
#              Unnamed: 4   Unnamed: 5 Unnamed: 6
# 0                   NaN          NaN        NaN
# 1                 Value  Description        NaN
# 2                   NaN          NaN        NaN
# 3                   NaN          NaN        NaN
# 4                   NaN          NaN        NaN
# ...                 ...          ...        ...
# 2590                  3          NaN        NaN
# 2591  Hydrochloric acid          NaN        NaN
# 2592        36.46 g/mol          NaN        NaN
# 2593                  1          NaN        NaN
# 2594                NaN          NaN        1/1
#
# [2595 rows x 7 columns]: ['Results Editor', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6']
# Columns in                           Results Editor  \
# 0                               Raw Data
# 1                                   Name
# 2               Task Internal Id: T1910
# 3                                    NaN
# 4                                    NaN
# ...                                  ...
# 2514                                 NaN
# 2515                                 NaN
# 2516                                 NaN
# 2517                                 NaN
# 2518  SystemInternal5/30/2024 3:46:57 AM
#
#                                              Unnamed: 1  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3     Sample Scope: Sample scope: Scope 1/1, Sample ...
# 4                                                   NaN
# ...                                                 ...
# 2514                                                NaN
# 2515                                                NaN
# 2516                                                NaN
# 2517                                                NaN
# 2518                                                NaN
#
#                                           Unnamed: 2      Unnamed: 3  \
# 0                                                NaN             NaN
# 1                                                NaN             NaN
# 2                                                NaN             NaN
# 3                                                NaN             NaN
# 4     Method Function: Method function: Sample (S1)              NaN
# ...                                              ...             ...
# 2514                                             NaN  Decimal places
# 2515                                             NaN       Substance
# 2516                                             NaN               M
# 2517                                             NaN               z
# 2518                                             NaN             NaN
#
#              Unnamed: 4   Unnamed: 5 Unnamed: 6
# 0                   NaN          NaN        NaN
# 1                 Value  Description        NaN
# 2                   NaN          NaN        NaN
# 3                   NaN          NaN        NaN
# 4                   NaN          NaN        NaN
# ...                 ...          ...        ...
# 2514                  3          NaN        NaN
# 2515  Hydrochloric acid          NaN        NaN
# 2516        36.46 g/mol          NaN        NaN
# 2517                  1          NaN        NaN
# 2518                NaN          NaN        1/1
#
# [2519 rows x 7 columns]: ['Results Editor', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6']
# Columns in                          Results Editor  \
# 0                              Raw Data
# 1                                  Name
# 2              Task Internal Id: T1993
# 3                                   NaN
# 4                                   NaN
# ...                                 ...
# 8013                                NaN
# 8014                                NaN
# 8015                                NaN
# 8016                                NaN
# 8017  SystemInternal6/9/2024 3:53:45 PM
#
#                                              Unnamed: 1  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3     Sample Scope: Sample scope: Scope 1/1, Sample ...
# 4                                                   NaN
# ...                                                 ...
# 8013                                                NaN
# 8014                                                NaN
# 8015                                                NaN
# 8016                                                NaN
# 8017                                                NaN
#
#                                           Unnamed: 2      Unnamed: 3  \
# 0                                                NaN             NaN
# 1                                                NaN             NaN
# 2                                                NaN             NaN
# 3                                                NaN             NaN
# 4     Method Function: Method function: Sample (S1)              NaN
# ...                                              ...             ...
# 8013                                             NaN  Decimal places
# 8014                                             NaN       Substance
# 8015                                             NaN               M
# 8016                                             NaN               z
# 8017                                             NaN             NaN
#
#              Unnamed: 4   Unnamed: 5 Unnamed: 6
# 0                   NaN          NaN        NaN
# 1                 Value  Description        NaN
# 2                   NaN          NaN        NaN
# 3                   NaN          NaN        NaN
# 4                   NaN          NaN        NaN
# ...                 ...          ...        ...
# 8013                  3          NaN        NaN
# 8014  Hydrochloric acid          NaN        NaN
# 8015        36.46 g/mol          NaN        NaN
# 8016                  1          NaN        NaN
# 8017                NaN          NaN        1/1
#
# [8018 rows x 7 columns]: ['Results Editor', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6']
# Columns in                         Results Editor  \
# 0                             Raw Data
# 1                                 Name
# 2             Task Internal Id: T2036
# 3                                  NaN
# 4                                  NaN
# 5                                  NaN
# 6                                  NaN
# 7                                  NaN
# 8                                  NaN
# 9                                  NaN
# 10                                 NaN
# 11                                 NaN
# 12                                 NaN
# 13                                 NaN
# 14                                 NaN
# 15                                 NaN
# 16                                 NaN
# 17                                 NaN
# 18                                 NaN
# 19                                 NaN
# 20                                 NaN
# 21                                 NaN
# 22                                 NaN
# 23                                 NaN
# 24                                 NaN
# 25                                 NaN
# 26                                 NaN
# 27                                 NaN
# 28                                 NaN
# 29                                 NaN
# 30                                 NaN
# 31                                 NaN
# 32                                 NaN
# 33                                 NaN
# 34                                 NaN
# 35                                 NaN
# 36                                 NaN
# 37                                 NaN
# 38  SystemInternal7/18/2024 4:58:29 PM
#
#                                            Unnamed: 1  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3   Sample Scope: Sample scope: Scope 1/1, Sample ...
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
#
#                                            Unnamed: 2         Unnamed: 3  \
# 0                                                 NaN                NaN
# 1                                                 NaN                NaN
# 2                                                 NaN                NaN
# 3                                                 NaN                NaN
# 4      Method Function: Method function: Sample (S1)                 NaN
# 5                                                 NaN      Creation time
# 6                                                 NaN  Sample start time
# 7                                                 NaN        Sample size
# 8                                                 NaN  Correction factor
# 9                                                 NaN        Temperature
# 10                                                NaN            Density
# 11  Method Function: Method function: Titration st...                NaN
# 12                                                NaN      Creation time
# 13    Method Function: Method function: Stir (Stir1)                 NaN
# 14                                                NaN      Creation time
# 15  Method Function: Method function: Titration (E...                NaN
# 16                                                NaN      Creation time
# 17                                                NaN      Terminated at
# 18                                                NaN                EST
# 19                                                NaN                VEX
# 20                                                NaN               VEND
# 21                                                NaN                  t
# 22                                                NaN               QEND
# 23                                                NaN                QEX
# 24  Method Function: Method function: Consumption ...                NaN
# 25                                                NaN      Creation time
# 26                                                NaN             Result
# 27                                                NaN     Decimal places
# 28                                                NaN          Substance
# 29                                                NaN                  M
# 30                                                NaN                  z
# 31    Method Function: Method function: Content (R2)                 NaN
# 32                                                NaN      Creation time
# 33                                                NaN             Result
# 34                                                NaN     Decimal places
# 35                                                NaN          Substance
# 36                                                NaN                  M
# 37                                                NaN                  z
# 38                                                NaN                NaN
#
#            Unnamed: 4   Unnamed: 5 Unnamed: 6
# 0                 NaN          NaN        NaN
# 1               Value  Description        NaN
# 2                 NaN          NaN        NaN
# 3                 NaN          NaN        NaN
# 4                 NaN          NaN        NaN
# 5     7/18/2024 16:40          NaN        NaN
# 6     7/18/2024 16:40          NaN        NaN
# 7             2.028 g          NaN        NaN
# 8                0.64          NaN        NaN
# 9             25.0 °C          NaN        NaN
# 10           1.0 g/mL          NaN        NaN
# 11                NaN          NaN        NaN
# 12    7/18/2024 16:40          NaN        NaN
# 13                NaN          NaN        NaN
# 14    7/18/2024 16:40          NaN        NaN
# 15                NaN          NaN        NaN
# 16    7/18/2024 16:41          NaN        NaN
# 17        Max. volume          NaN        NaN
# 18           2.156 pH          NaN        NaN
# 19       10.000000 mL          NaN        NaN
# 20       10.000000 mL          NaN        NaN
# 21          01:26 min          NaN        NaN
# 22      1.000000 mmol          NaN        NaN
# 23      1.000000 mmol          NaN        NaN
# 24                NaN          NaN        NaN
# 25    7/18/2024 16:42          NaN        NaN
# 26             NaN mL          NaN        NaN
# 27                  4          NaN        NaN
# 28  Hydrochloric acid          NaN        NaN
# 29        36.46 g/mol          NaN        NaN
# 30                  1          NaN        NaN
# 31                NaN          NaN        NaN
# 32    7/18/2024 16:42          NaN        NaN
# 33           NaN mL/g          NaN        NaN
# 34                  3          NaN        NaN
# 35  Hydrochloric acid          NaN        NaN
# 36        36.46 g/mol          NaN        NaN
# 37                  1          NaN        NaN
# 38                NaN          NaN      1-Jan  : ['Results Editor', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6']
# Columns in                           Results Editor  \
# 0                               Raw Data
# 1                                   Name
# 2               Task Internal Id: T2022
# 3                                    NaN
# 4                                    NaN
# ...                                  ...
# 5564                                 NaN
# 5565                                 NaN
# 5566                                 NaN
# 5567                                 NaN
# 5568  SystemInternal6/18/2024 5:50:53 PM
#
#                                              Unnamed: 1  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3     Sample Scope: Sample scope: Scope 1/1, Sample ...
# 4                                                   NaN
# ...                                                 ...
# 5564                                                NaN
# 5565                                                NaN
# 5566                                                NaN
# 5567                                                NaN
# 5568                                                NaN
#
#                                           Unnamed: 2      Unnamed: 3  \
# 0                                                NaN             NaN
# 1                                                NaN             NaN
# 2                                                NaN             NaN
# 3                                                NaN             NaN
# 4     Method Function: Method function: Sample (S1)              NaN
# ...                                              ...             ...
# 5564                                             NaN  Decimal places
# 5565                                             NaN       Substance
# 5566                                             NaN               M
# 5567                                             NaN               z
# 5568                                             NaN             NaN
#
#              Unnamed: 4   Unnamed: 5 Unnamed: 6
# 0                   NaN          NaN        NaN
# 1                 Value  Description        NaN
# 2                   NaN          NaN        NaN
# 3                   NaN          NaN        NaN
# 4                   NaN          NaN        NaN
# ...                 ...          ...        ...
# 5564                  3          NaN        NaN
# 5565  Hydrochloric acid          NaN        NaN
# 5566        36.46 g/mol          NaN        NaN
# 5567                  1          NaN        NaN
# 5568                NaN          NaN      1-Jan
#
# [5569 rows x 7 columns]: ['Results Editor', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6']
# Columns in                           Results Editor  \
# 0                               Raw Data
# 1                                   Name
# 2               Task Internal Id: T2016
# 3                                    NaN
# 4                                    NaN
# ...                                  ...
# 3506                                 NaN
# 3507                                 NaN
# 3508                                 NaN
# 3509                                 NaN
# 3510  SystemInternal6/14/2024 6:49:50 PM
#
#                                              Unnamed: 1  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3     Sample Scope: Sample scope: Scope 1/1, Sample ...
# 4                                                   NaN
# ...                                                 ...
# 3506                                                NaN
# 3507                                                NaN
# 3508                                                NaN
# 3509                                                NaN
# 3510                                                NaN
#
#                                           Unnamed: 2      Unnamed: 3  \
# 0                                                NaN             NaN
# 1                                                NaN             NaN
# 2                                                NaN             NaN
# 3                                                NaN             NaN
# 4     Method Function: Method function: Sample (S1)              NaN
# ...                                              ...             ...
# 3506                                             NaN  Decimal places
# 3507                                             NaN       Substance
# 3508                                             NaN               M
# 3509                                             NaN               z
# 3510                                             NaN             NaN
#
#              Unnamed: 4   Unnamed: 5 Unnamed: 6
# 0                   NaN          NaN        NaN
# 1                 Value  Description        NaN
# 2                   NaN          NaN        NaN
# 3                   NaN          NaN        NaN
# 4                   NaN          NaN        NaN
# ...                 ...          ...        ...
# 3506                  3          NaN        NaN
# 3507  Hydrochloric acid          NaN        NaN
# 3508        36.46 g/mol          NaN        NaN
# 3509                  1          NaN        NaN
# 3510                NaN          NaN        1/1
#
# [3511 rows x 7 columns]: ['Results Editor', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6']
# Columns in                           Results Editor  \
# 0                               Raw Data
# 1                                   Name
# 2               Task Internal Id: T1999
# 3                                    NaN
# 4                                    NaN
# ...                                  ...
# 1752                                 NaN
# 1753                                 NaN
# 1754                                 NaN
# 1755                                 NaN
# 1756  SystemInternal6/13/2024 7:32:55 PM
#
#                                              Unnamed: 1  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3     Sample Scope: Sample scope: Scope 1/1, Sample ...
# 4                                                   NaN
# ...                                                 ...
# 1752                                                NaN
# 1753                                                NaN
# 1754                                                NaN
# 1755                                                NaN
# 1756                                                NaN
#
#                                           Unnamed: 2      Unnamed: 3  \
# 0                                                NaN             NaN
# 1                                                NaN             NaN
# 2                                                NaN             NaN
# 3                                                NaN             NaN
# 4     Method Function: Method function: Sample (S1)              NaN
# ...                                              ...             ...
# ...
#  18                 NaN     NaN            NaN          NaN               NaN
#  19                 NaN     NaN            NaN          NaN               NaN
#  20                 NaN     NaN            NaN          NaN               NaN
#  21                 NaN     NaN            NaN          NaN               NaN
#  22                 NaN     NaN            NaN          NaN               NaN
#  23                 NaN     NaN            NaN          NaN               NaN
#  24                 NaN     NaN            NaN          NaN               NaN
#  25                 NaN     NaN            NaN          NaN               NaN
#  26                 NaN     NaN            NaN          NaN               NaN
#  27                 NaN     NaN            NaN          NaN               NaN
#  28                 NaN     NaN            NaN          NaN               NaN
#  29                 NaN     NaN            NaN          NaN               NaN
#  30                 NaN     NaN            NaN          NaN               NaN
#  31                 NaN     NaN            NaN          NaN               NaN
#  32                 NaN     NaN            NaN          NaN               NaN
#  33                 NaN     NaN            NaN          NaN               NaN
#  34                 NaN     NaN            NaN          NaN               NaN
#  35                 NaN     NaN            NaN          NaN               NaN
#  36                 NaN     NaN            NaN          NaN               NaN
#  37                 NaN     NaN            NaN          NaN               NaN
#  38                 NaN     NaN            NaN          NaN               NaN
#  39                 NaN     NaN            NaN          NaN               NaN
#  40                 NaN     NaN            NaN          NaN               NaN
#  41                 NaN     NaN            NaN          NaN               NaN
#  42                 NaN     NaN            NaN          NaN               NaN
#  43                 NaN     NaN            NaN          NaN               NaN
#  44                 NaN     NaN            NaN          NaN               NaN
#  45                 NaN     NaN            NaN          NaN               NaN
#  46                 NaN     NaN            NaN          NaN               NaN
#  47                 NaN     NaN            NaN          NaN               NaN
#  48                 NaN     NaN            NaN          NaN               NaN
#
#      Unnamed: 25  YM20_conditional
#  0           NaN               NaN
#  1           NaN               NaN
#  2           NaN               NaN
#  3           NaN               NaN
#  4           NaN               NaN
#  5           NaN               NaN
#  6           NaN               NaN
#  7           NaN               NaN
#  8           NaN               NaN
#  9           NaN               NaN
#  10          NaN               NaN
#  11          NaN               NaN
#  12          NaN               NaN
#  13          NaN               NaN
#  14          NaN               NaN
#  15          NaN               NaN
#  16          NaN               NaN
#  17          NaN               NaN
#  18          NaN               NaN
#  19          NaN               NaN
#  20          NaN               NaN
#  21          NaN               NaN
#  22          NaN               NaN
#  23          NaN               NaN
#  24          NaN               NaN
#  25          NaN               NaN
#  26          NaN               NaN
#  27          NaN               NaN
#  28          NaN               NaN
#  29          NaN               NaN
#  30          NaN               NaN
#  31          NaN               NaN
#  32          NaN               NaN
#  33          NaN               NaN
#  34          NaN               NaN
#  35          NaN               NaN
#  36          NaN               NaN
#  37          NaN               NaN
#  38          NaN               NaN
#  39          NaN               NaN
#  40          NaN               NaN
#  41          NaN               NaN
#  42          NaN               NaN
#  43          NaN               NaN
#  44          NaN               NaN
#  45          NaN               NaN
#  46          NaN               NaN
#  47          NaN               NaN
#  48          NaN               NaN
#
#  [49 rows x 27 columns],
#     Sample ID                                              Batch  \
#  0    LSH-182  North Carolina FQ Study 3 T0 LSH-182_Harvest2 ...
#  1    LSH-183  North Carolina FQ Study 3 T0 LSH-182_Harvest2 ...
#  2    LSH-184  North Carolina FQ Study 3 T0 LSH-182_Harvest2 ...
#  3    LSH-185  North Carolina FQ Study 3 T0 LSH-182_Harvest2 ...
#  4    LSH-186  North Carolina FQ Study 3 T0 LSH-182_Harvest2 ...
#  5    LSH-187  North Carolina FQ Study 3 T0 LSH-182_Harvest2 ...
#  6    LSH-188  North Carolina FQ Study 3 T0 LSH-182_Harvest2 ...
#  7    LSH-189  North Carolina FQ Study 3 T0 LSH-182_Harvest2 ...
#  8    LSH-190  North Carolina FQ Study 3 T0 LSH-182_Harvest2 ...
#  9    LSH-191  North Carolina FQ Study 3 T0 LSH-182_Harvest2 ...
#  10   LSH-192  North Carolina FQ Study 3 T0 LSH-182_Harvest2 ...
#  11   LSH-193  North Carolina FQ Study 3 T0 LSH-182_Harvest2 ...
#  12   LSH-194  North Carolina FQ Study 3 T0 LSH-182_Harvest2 ...
#  13   LSH-195  North Carolina FQ Study 3 T0 LSH-182_Harvest2 ...
#  14   LSH-196  North Carolina FQ Study 3 T0 LSH-182_Harvest2 ...
#  15   LSH-197  North Carolina FQ Study 3 T0 LSH-182_Harvest2 ...
#  16   LSH-198  North Carolina FQ Study 3 T0 LSH-182_Harvest2 ...
#  17   LSH-200  North Carolina FQ Study 3 T0 LSH-182_Harvest2 ...
#  18   LSH-202  North Carolina FQ Study 3 T0 LSH-182_Harvest2 ...
#  19   LSH-203  North Carolina FQ Study 3 T0 LSH-182_Harvest2 ...
#  20   LSH-205  North Carolina FQ Study 3 T0 LSH-182_Harvest2 ...
#  21   LSH-207  North Carolina FQ Study 3 T0 LSH-182_Harvest2 ...
#  22   LSH-208  North Carolina FQ Study 3 T0 LSH-182_Harvest2 ...
#  23   LSH-209  North Carolina FQ Study 3 T0 LSH-182_Harvest2 ...
#  24   LSH-210  North Carolina FQ Study 3 T0 LSH-182_Harvest2 ...
#
#            Unnamed: 2   F1mm     FM    DFM  BurstStrain    SFM    AFM   LDFM  \
#  0   AVERAGE("BATCH")  0.555  1.715  3.718       25.895  0.453  3.623  4.351
#  1   AVERAGE("BATCH")  0.555  1.715  3.718       25.895  0.453  3.623  4.351
#  2   AVERAGE("BATCH")  0.555  1.715  3.718       25.895  0.453  3.623  4.351
#  3   AVERAGE("BATCH")  0.555  1.715  3.718       25.895  0.453  3.623  4.351
#  4   AVERAGE("BATCH")  0.555  1.715  3.718       25.895  0.453  3.623  4.351
#  5   AVERAGE("BATCH")  0.555  1.715  3.718       25.895  0.453  3.623  4.351
#  6   AVERAGE("BATCH")  0.555  1.715  3.718       25.895  0.453  3.623  4.351
#  7   AVERAGE("BATCH")  0.555  1.715  3.718       25.895  0.453  3.623  4.351
#  8   AVERAGE("BATCH")  0.555  1.715  3.718       25.895  0.453  3.623  4.351
#  9   AVERAGE("BATCH")  0.555  1.715  3.718       25.895  0.453  3.623  4.351
#  10  AVERAGE("BATCH")  0.555  1.715  3.718       25.895  0.453  3.623  4.351
#  11  AVERAGE("BATCH")  0.555  1.715  3.718       25.895  0.453  3.623  4.351
#  12  AVERAGE("BATCH")  0.555  1.715  3.718       25.895  0.453  3.623  4.351
#  13  AVERAGE("BATCH")  0.555  1.715  3.718       25.895  0.453  3.623  4.351
#  14  AVERAGE("BATCH")  0.555  1.715  3.718       25.895  0.453  3.623  4.351
#  15  AVERAGE("BATCH")  0.555  1.715  3.718       25.895  0.453  3.623  4.351
#  16  AVERAGE("BATCH")  0.555  1.715  3.718       25.895  0.453  3.623  4.351
#  17  AVERAGE("BATCH")  0.555  1.715  3.718       25.895  0.453  3.623  4.351
#  18  AVERAGE("BATCH")  0.555  1.715  3.718       25.895  0.453  3.623  4.351
#  19  AVERAGE("BATCH")  0.555  1.715  3.718       25.895  0.453  3.623  4.351
#  20  AVERAGE("BATCH")  0.555  1.715  3.718       25.895  0.453  3.623  4.351
#  21  AVERAGE("BATCH")  0.555  1.715  3.718       25.895  0.453  3.623  4.351
#  22  AVERAGE("BATCH")  0.555  1.715  3.718       25.895  0.453  3.623  4.351
#  23  AVERAGE("BATCH")  0.555  1.715  3.718       25.895  0.453  3.623  4.351
#  24  AVERAGE("BATCH")  0.555  1.715  3.718       25.895  0.453  3.623  4.351
#
#      ...  YM_20pct_BurstStrain  YM_80pct_BurstStrain  YM_100pct_BurstStrain  \
#  0   ...                 2.083                 2.236                   2.13
#  1   ...                 2.083                 2.236                   2.13
#  2   ...                 2.083                 2.236                   2.13
#  3   ...                 2.083                 2.236                   2.13
#  4   ...                 2.083                 2.236                   2.13
#  5   ...                 2.083                 2.236                   2.13
#  6   ...                 2.083                 2.236                   2.13
#  7   ...                 2.083                 2.236                   2.13
#  8   ...                 2.083                 2.236                   2.13
#  9   ...                 2.083                 2.236                   2.13
#  10  ...                 2.083                 2.236                   2.13
#  11  ...                 2.083                 2.236                   2.13
#  12  ...                 2.083                 2.236                   2.13
#  13  ...                 2.083                 2.236                   2.13
#  14  ...                 2.083                 2.236                   2.13
#  15  ...                 2.083                 2.236                   2.13
#  16  ...                 2.083                 2.236                   2.13
#  17  ...                 2.083                 2.236                   2.13
#  18  ...                 2.083                 2.236                   2.13
#  19  ...                 2.083                 2.236                   2.13
#  20  ...                 2.083                 2.236                   2.13
#  21  ...                 2.083                 2.236                   2.13
#  22  ...                 2.083                 2.236                   2.13
#  23  ...                 2.083                 2.236                   2.13
#  24  ...                 2.083                 2.236                   2.13
#
#      Youngs Modulus 1-2 %  Stem_Scar_Diameter  Weight  Diameter_flat  \
#  0                  1.943                   0       0         14.435
#  1                  1.943                   0       0         14.435
#  2                  1.943                   0       0         14.435
#  3                  1.943                   0       0         14.435
#  4                  1.943                   0       0         14.435
#  5                  1.943                   0       0         14.435
#  6                  1.943                   0       0         14.435
#  7                  1.943                   0       0         14.435
#  8                  1.943                   0       0         14.435
#  9                  1.943                   0       0         14.435
#  10                 1.943                   0       0         14.435
#  11                 1.943                   0       0         14.435
#  12                 1.943                   0       0         14.435
#  13                 1.943                   0       0         14.435
#  14                 1.943                   0       0         14.435
#  15                 1.943                   0       0         14.435
#  16                 1.943                   0       0         14.435
#  17                 1.943                   0       0         14.435
#  18                 1.943                   0       0         14.435
#  19                 1.943                   0       0         14.435
#  20                 1.943                   0       0         14.435
#  21                 1.943                   0       0         14.435
#  22                 1.943                   0       0         14.435
#  23                 1.943                   0       0         14.435
#  24                 1.943                   0       0         14.435
#
#      Stress_Area  YM20_conditional  YM30_conditional
#  0         3.142             2.184             1.747
#  1         3.142             2.184             1.747
#  2         3.142             2.184             1.747
#  3         3.142             2.184             1.747
#  4         3.142             2.184             1.747
#  5         3.142             2.184             1.747
#  6         3.142             2.184             1.747
#  7         3.142             2.184             1.747
#  8         3.142             2.184             1.747
#  9         3.142             2.184             1.747
#  10        3.142             2.184             1.747
#  11        3.142             2.184             1.747
#  12        3.142             2.184             1.747
#  13        3.142             2.184             1.747
#  14        3.142             2.184             1.747
#  15        3.142             2.184             1.747
#  16        3.142             2.184             1.747
#  17        3.142             2.184             1.747
#  18        3.142             2.184             1.747
#  19        3.142             2.184             1.747
#  20        3.142             2.184             1.747
#  21        3.142             2.184             1.747
#  22        3.142             2.184             1.747
#  23        3.142             2.184             1.747
#  24        3.142             2.184             1.747
#
#  [25 rows x 26 columns]]
# [Empty DataFrame
#  Columns: [unique id, autotitration sample size (g), autotitration veq1 (ml), autotitration est (pH)]
#  Index: [],
#  Empty DataFrame
#  Columns: [unique id, autotitration sample size (g), autotitration veq1 (ml), autotitration est (pH)]
#  Index: [],
#  Empty DataFrame
#  Columns: [unique id, autotitration sample size (g), autotitration veq1 (ml), autotitration est (pH)]
#  Index: [],
#  Empty DataFrame
#  Columns: [unique id, autotitration sample size (g), autotitration veq1 (ml), autotitration est (pH)]
#  Index: [],
#  Empty DataFrame
#  Columns: [unique id, autotitration sample size (g), autotitration veq1 (ml), autotitration est (pH)]
#  Index: [],
#  Empty DataFrame
#  Columns: [unique id, autotitration sample size (g), autotitration veq1 (ml), autotitration est (pH)]
#  Index: [],
#  Empty DataFrame
#  Columns: [unique id, autotitration sample size (g), autotitration veq1 (ml), autotitration est (pH)]
#  Index: [],
#  Empty DataFrame
#  Columns: [unique id, autotitration sample size (g), autotitration veq1 (ml), autotitration est (pH)]
#  Index: [],
#  Empty DataFrame
#  Columns: [unique id, autotitration sample size (g), autotitration veq1 (ml), autotitration est (pH)]
#  Index: [],
#  Empty DataFrame
#  Columns: [unique id, autotitration sample size (g), autotitration veq1 (ml), autotitration est (pH)]
#  Index: [],
#  Empty DataFrame
#  Columns: [unique id, autotitration sample size (g), autotitration veq1 (ml), autotitration est (pH)]
#  Index: [],
#  Empty DataFrame
#  Columns: [unique id, autotitration sample size (g), autotitration veq1 (ml), autotitration est (pH)]
#  Index: [],
#  Empty DataFrame
#  Columns: [unique id, autotitration sample size (g), autotitration veq1 (ml), autotitration est (pH)]
#  Index: [],
#  Empty DataFrame
#  Columns: [unique id, autotitration sample size (g), autotitration veq1 (ml), autotitration est (pH)]
#  Index: [],
#  Empty DataFrame
#  Columns: [unique id, autotitration sample size (g), autotitration veq1 (ml), autotitration est (pH)]
#  Index: [],
#  Empty DataFrame
#  Columns: [unique id, autotitration sample size (g), autotitration veq1 (ml), autotitration est (pH)]
#  Index: [],
#  Empty DataFrame
#  Columns: [unique id, autotitration sample size (g), autotitration veq1 (ml), autotitration est (pH)]
#  Index: [],
#  Empty DataFrame
#  Columns: [unique id, autotitration sample size (g), autotitration veq1 (ml), autotitration est (pH)]
#  Index: []]
